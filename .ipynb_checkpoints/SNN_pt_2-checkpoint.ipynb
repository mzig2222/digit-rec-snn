# %%
pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\mzig2\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (1.17.4)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\mzig2\anaconda3\lib\site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install import_ipynb
# Out:
# Requirement already satisfied: import_ipynb in c:\users\mzig2\anaconda3\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %% [markdown]
# ## Data Management

# %%
from sklearn.datasets import load_digits
 
digits = load_digits()
import matplotlib.pyplot as plt 
plt.matshow(digits.images[0]) 
plt.show()

# %%
#flattening to 1D arrays
#partitioning to training set, testing set, validation set
from sklearn.model_selection import train_test_split
X_train, X_other, y_train, y_other = train_test_split(digits.data, digits.images, test_size=0.2, shuffle=False)
X_test, X_val, y_test, y_val = train_test_split(X_other, y_other, test_size=0.5, shuffle=False)
print("Numbers to train: " + str(len(X_train)))
print("Numbers to test: " + str(len(X_test)))
print("Numbers to validate: " + str(len(X_val)))
# Out:
# Numbers to train: 1437
# Numbers to test: 180
# Numbers to validate: 180

# %% [markdown]
# ### Sample image representing 6

# %%
i=36
plt.matshow(X_test[i].reshape(8,8))
print(digits.target[len(X_train)+i])
# Out:
# 6

# %% [markdown]
# ## Poisson Encoding

# %% [markdown]
# For this modified SNN, we decided to employ a Poisson Encoding scheme in order to generate a spike train representation for each of our images. Citing this paper https://arxiv.org/ftp/arxiv/papers/1604/1604.06751.pdf, our algorithm for doing so was as follows:
#
# - normalize all r rate (pixel intensity) values to be between 0 and 1
# - generate M uniform random numbers between 0 and 1 where M is equal to the number of bins of time we're examining spiking   activity (since dT = 1, M will be equal to the size of the array)
# - for all i in M random numbers in rand, if r[i] > rand[i], generate 1 spike
#
# After executing this process, 3 arrays will be returned of size M: one containing the normalized pixel intensities of each bin, one containing their binary spike values, and one consisting of the maximum amount of intensity at each index where a spike occurs for plotting purposes.

# %%
def poissonEncoding(rates):
    """
    Transforms a 1D array of inputs representing an image into spike train representation utilizing Poisson method of
    encoding
    
    Params:
        rates: 1D array of inputs (in this case, pixel intensitiies corresponding to our image)
    Returns:
        n_rates: Normalized set of input pixel values (represents probabilities of a spike occurring at each dT)
        bin_spikes: 1D array of binary values representing timesteps in which spikes occur
        p_spikes: 1D array representing pixel intensities of spike train representation for plotting/computation purposes
        
    """
    dT = 1
    
    max = np.amax(rates)
    n_rates = (rates*dT)/max
    
    rand = np.random.uniform(0,1, len(rates))
    bin_spikes = np.zeros(len(rates))
    pix_spikes = np.zeros(len(rates))
    
    for i in range(len(rates)):
        if n_rates[i] > rand[i]:
            bin_spikes[i] = 1
            pix_spikes[i] = max
                    
    return n_rates, bin_spikes, pix_spikes

# %%
plt.matshow(np.reshape(X_train[0], (8,8))) 
print(digits.target[0])
n, b, p = poissonEncoding(X_train[0])
plt.matshow(p.reshape(8,8))
plt.show()

len(digits.images)
# Out:
# 0
# 1797

# %% [markdown]
#  ## Network Functions

# %%
def train(X, Y, val, l_rt, init, epochs):
    
    weights = init
    
    for i in range(epochs):
        
        print("epoch: ", i)
        print("training......")
        for x in range(len(X)):
            
            true_index = digits.target[x]
            #print("index: ", x, " true index: ", true_index)
            in_neurons = X[x]
            out_neurons = Y[x]
            
            X_n_rts, X_bins, X_pixs = poissonEncoding(in_neurons)
                        
            weight_adjs = np.zeros((len(in_neurons),10))
            
            y_out  = np.zeros((10,len(in_neurons)))
            y_out[true_index] = out_neurons.flatten()
                        
            for pix in range(len(in_neurons)):
                for digit in range(10):
                   weight_adjs[pix][digit] = l_rt*X_bins[pix]*y_out[digit][pix]
                
            weights = weights + weight_adjs
            
            if (i == 0) and (x % 250 == 0):
                print("********************")
                print("validating after ",x,"th image:")
                validate(X,val,weights.T,0,len(X_train)+len(X_test))
                
        print("weights after epoch ", i,": ", weights, "\n")
        validate(X, val, weights.T, 0, len(X_train)+len(X_test))
        print("------------------------------")
        
        
    return weights.T


def validate(train, val, weights, ind_train, ind_val):
    
    train_correct = 0
    val_correct = 0
    
    for i in range(len(train)):
        prediction = _predict(train[i], weights)
        if prediction == digits.target[ind_train+i]:
            train_correct+=1
    train_accuracy = train_correct/len(train)
    print("training accuracy: ", train_accuracy)
    
    for j in range(len(val)):
        prediction = _predict(val[j], weights)
        if prediction == digits.target[ind_val+j]:
            val_correct+=1
    val_accuracy = val_correct/len(val)
    print("validation accuracy: ", val_accuracy)
    
    print("total accuracy: ", (train_correct+val_correct)/(len(train)+len(val)))
    
        

def predict(test, weights, targ):
    
    print("image value: ", targ)
    
    n, spikes, p = poissonEncoding(test)
    outs = np.zeros(len(weights))
    for i in range(len(weights)):
        outs[i] = np.dot(spikes, weights[i])
    
    prediction = np.argmax(outs)
    
    print("predicted value: ", prediction)
    
    if (prediction == targ):
        return True
    else:
        return False
    
def _predict(test, weights):
    
    n, spikes, p = poissonEncoding(test)
    outs = np.zeros(len(weights))
    
    for i in range(len(weights)):
        outs[i] = np.dot(spikes, weights[i])
    
    return np.argmax(outs)
    
def sim(test, weights, ind_targ):
    
    correct = 0
    
    for i in range(len(test)):
        
        x = predict(test[i], weights, digits.target[ind_targ+i])
        
        print("prediction correct: ", x)
        print("------------------------------")
        
        if x:
            correct += 1
            
    return correct/len(test)

# %% [markdown]
# ## Training

# %%
init_weights = np.zeros((len(X_train[0]),10))

#w_i,j = w_out,pix
weights = train(X_train, y_train, X_val, 0.0008, init_weights, 3)
# Out:
# epoch:  0
# training......
# ********************
# validating after  0 th image:
# training accuracy:  0.09951287404314545
# validation accuracy:  0.08888888888888889
# total accuracy:  0.09833024118738404
# ********************
# validating after  250 th image:
# training accuracy:  0.6409185803757829
# validation accuracy:  0.6222222222222222
# total accuracy:  0.6388373531230674
# ********************
# validating after  500 th image:
# training accuracy:  0.6235212247738344
# validation accuracy:  0.5944444444444444
# total accuracy:  0.6202844774273346
# ********************
# validating after  750 th image:
# training accuracy:  0.6339596381350034
# validation accuracy:  0.5833333333333334
# total accuracy:  0.6283240568954854
# ********************
# validating after  1000 th image:
# training accuracy:  0.6903270702853166
# validation accuracy:  0.5777777777777777
# total accuracy:  0.6777983920841064
# ********************
# validating after  1250 th image:
# training accuracy:  0.697286012526096
# validation accuracy:  0.65
# total accuracy:  0.6920222634508348
# weights after epoch  0 :  [[0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 4.0000e-03 5.6000e-03 0.0000e+00 2.1600e-02
#   0.0000e+00 0.0000e+00 0.0000e+00 4.0000e-03]
#  [1.4560e-01 1.2240e-01 7.6240e-01 6.4240e-01 1.6000e-03 9.0400e-01
#   3.3600e-02 2.3280e-01 2.9040e-01 3.0560e-01]
#  [1.2712e+00 8.6960e-01 1.4736e+00 1.4872e+00 5.2320e-01 1.2848e+00
#   9.3520e-01 1.2656e+00 9.9760e-01 1.1664e+00]
#  [1.0352e+00 9.5600e-01 9.0880e-01 1.3936e+00 1.1448e+00 1.4808e+00
#   9.4400e-01 1.5200e+00 1.1272e+00 9.6160e-01]
#  [1.5760e-01 4.7280e-01 1.6960e-01 5.9600e-01 9.8400e-02 1.3096e+00
#   8.4800e-02 1.1304e+00 4.4720e-01 4.5200e-01]
#  [0.0000e+00 2.3200e-02 0.0000e+00 3.4400e-02 1.0400e-02 2.9680e-01
#   0.0000e+00 5.2560e-01 1.3600e-02 1.1200e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.7600e-02 0.0000e+00
#   0.0000e+00 7.3600e-02 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.3200e-02 2.4000e-03 2.9600e-01 2.2080e-01 8.0000e-04 2.4480e-01
#   1.6000e-03 2.0000e-02 9.4400e-02 7.5200e-02]
#  [1.2048e+00 2.5040e-01 1.5056e+00 1.2728e+00 1.9520e-01 1.6456e+00
#   4.4240e-01 9.7200e-01 1.2576e+00 1.2664e+00]
#  [1.3072e+00 1.3552e+00 1.0504e+00 6.8400e-01 1.4112e+00 1.1664e+00
#   1.5752e+00 1.0640e+00 1.0184e+00 8.0480e-01]
#  [1.0048e+00 1.5144e+00 1.2672e+00 9.6720e-01 8.1440e-01 6.2320e-01
#   4.5680e-01 1.0088e+00 8.5680e-01 7.8320e-01]
#  [1.0008e+00 8.4160e-01 4.8000e-01 1.1488e+00 1.4160e-01 4.7040e-01
#   6.2400e-02 1.3360e+00 1.1088e+00 1.0120e+00]
#  [3.5200e-02 7.5200e-02 2.4800e-02 1.1920e-01 9.2000e-02 1.3600e-01
#   0.0000e+00 5.0320e-01 9.5200e-02 1.6000e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 2.1600e-02 0.0000e+00
#   0.0000e+00 4.5600e-02 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [1.6800e-01 4.9600e-02 3.2640e-01 1.5200e-01 3.3600e-02 3.2160e-01
#   2.1600e-02 2.3200e-02 1.6000e-01 1.8000e-01]
#  [1.4984e+00 5.3920e-01 6.5440e-01 2.8960e-01 9.7440e-01 1.4824e+00
#   1.3416e+00 3.8240e-01 1.0600e+00 1.1864e+00]
#  [3.9040e-01 1.6536e+00 2.7280e-01 1.1760e-01 1.1600e+00 4.0000e-01
#   7.6640e-01 9.6800e-02 5.5840e-01 3.5280e-01]
#  [1.2160e-01 1.5352e+00 1.1288e+00 1.1920e+00 3.7120e-01 9.8400e-02
#   2.4800e-02 5.0960e-01 6.4560e-01 5.7440e-01]
#  [1.0976e+00 6.3440e-01 4.8960e-01 8.2000e-01 4.4800e-01 2.7200e-02
#   6.4000e-03 1.0488e+00 1.0912e+00 1.4624e+00]
#  [1.6720e-01 1.8400e-02 3.5200e-02 4.0000e-02 3.7280e-01 4.0000e-03
#   0.0000e+00 2.0480e-01 5.2000e-02 1.8480e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.4400e-02 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 2.4000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.4960e-01 1.4400e-01 5.5200e-02 1.5200e-02 2.3120e-01 2.8800e-01
#   8.2400e-02 1.2000e-02 2.0000e-02 8.6400e-02]
#  [1.2072e+00 8.6400e-01 8.7200e-02 4.0800e-02 1.5344e+00 1.4832e+00
#   1.4784e+00 2.9040e-01 7.1360e-01 9.8400e-01]
#  [7.5200e-02 1.6824e+00 3.5520e-01 7.3760e-01 4.5280e-01 1.1352e+00
#   7.0880e-01 4.8240e-01 1.2960e+00 1.1768e+00]
#  [4.8000e-03 1.4904e+00 1.1296e+00 1.5880e+00 6.2320e-01 7.4720e-01
#   3.1760e-01 1.2104e+00 1.3208e+00 1.3456e+00]
#  [6.4960e-01 5.1440e-01 3.4800e-01 4.2960e-01 8.9840e-01 2.7520e-01
#   1.1360e-01 1.1760e+00 5.2480e-01 1.5320e+00]
#  [3.8240e-01 9.6000e-03 0.0000e+00 1.6000e-03 4.0800e-01 1.9200e-02
#   6.4000e-03 3.9200e-01 1.8400e-02 2.0800e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.3600e-01 3.1200e-02 0.0000e+00 2.4000e-03 6.3360e-01 7.8400e-02
#   1.3760e-01 3.1200e-02 3.2000e-03 2.4000e-03]
#  [9.3520e-01 6.1280e-01 5.2000e-02 1.6800e-02 1.5664e+00 6.4320e-01
#   1.6576e+00 7.7520e-01 4.8880e-01 2.7920e-01]
#  [2.0000e-02 1.2832e+00 8.6000e-01 3.5840e-01 8.4960e-01 7.3600e-01
#   1.2912e+00 1.4192e+00 1.4704e+00 4.7920e-01]
#  [0.0000e+00 1.4856e+00 9.1840e-01 1.1568e+00 1.3224e+00 8.2560e-01
#   1.1168e+00 1.5728e+00 1.2904e+00 4.2800e-01]
#  [6.9120e-01 4.1760e-01 9.5200e-02 1.1960e+00 1.4816e+00 5.7360e-01
#   9.2800e-01 1.1104e+00 2.6560e-01 1.1368e+00]
#  [4.2240e-01 9.6000e-03 0.0000e+00 9.4400e-02 2.9680e-01 6.6400e-02
#   1.3360e-01 2.1760e-01 4.0000e-03 3.0320e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [1.0560e-01 2.0000e-02 2.4800e-02 3.2800e-02 4.5200e-01 2.4000e-03
#   3.6000e-02 5.2000e-02 4.4800e-02 0.0000e+00]
#  [1.2640e+00 4.6480e-01 4.5440e-01 4.5600e-02 1.0800e+00 8.3200e-02
#   1.6072e+00 3.6800e-01 1.0424e+00 1.8400e-02]
#  [7.3600e-02 1.0296e+00 1.1120e+00 1.1200e-02 1.1792e+00 2.8640e-01
#   1.0016e+00 1.0280e+00 7.5680e-01 3.9200e-02]
#  [6.7200e-02 1.4808e+00 5.5280e-01 2.2080e-01 1.6032e+00 7.0480e-01
#   4.2160e-01 9.9440e-01 7.3280e-01 1.5120e-01]
#  [9.6240e-01 4.6960e-01 8.2400e-02 1.1888e+00 1.0576e+00 7.5840e-01
#   8.2320e-01 2.2960e-01 6.3200e-01 8.5920e-01]
#  [3.2560e-01 6.4000e-03 4.1600e-02 4.7120e-01 5.1200e-02 1.4480e-01
#   7.6960e-01 1.9200e-02 3.8400e-02 3.5520e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   8.0000e-03 0.0000e+00 0.0000e+00 3.2000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 7.2000e-03 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [1.6000e-02 1.6000e-03 6.9600e-02 4.8000e-02 4.8800e-02 2.9600e-02
#   4.0000e-03 0.0000e+00 2.5600e-02 6.4000e-03]
#  [1.2912e+00 3.7360e-01 1.0640e+00 5.8880e-01 2.1840e-01 3.2480e-01
#   8.7360e-01 9.6800e-02 1.0424e+00 5.1840e-01]
#  [7.4560e-01 1.1128e+00 1.3912e+00 4.4000e-01 6.1200e-01 7.0240e-01
#   1.2296e+00 1.2520e+00 4.9680e-01 2.9920e-01]
#  [8.4720e-01 1.4784e+00 1.0856e+00 5.5840e-01 1.4184e+00 1.0128e+00
#   3.2160e-01 4.1680e-01 7.3520e-01 3.4560e-01]
#  [1.3128e+00 7.9360e-01 8.3040e-01 1.3552e+00 2.7120e-01 5.5760e-01
#   1.0424e+00 2.4000e-03 8.2880e-01 9.6800e-01]
#  [1.2720e-01 1.2880e-01 4.9760e-01 5.0080e-01 8.0000e-04 6.4800e-02
#   1.0504e+00 0.0000e+00 1.7200e-01 4.9200e-01]
#  [0.0000e+00 4.5600e-02 3.2000e-03 3.2000e-03 0.0000e+00 0.0000e+00
#   2.9600e-02 0.0000e+00 0.0000e+00 1.6000e-03]
#  [0.0000e+00 0.0000e+00 8.0000e-04 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 2.0000e-02 1.3600e-02 8.0000e-04 3.6800e-02
#   0.0000e+00 0.0000e+00 8.0000e-04 8.0000e-04]
#  [1.7600e-01 1.4000e-01 8.5360e-01 7.7920e-01 2.3200e-02 1.0176e+00
#   2.2400e-02 4.5840e-01 3.5120e-01 3.3920e-01]
#  [1.3152e+00 9.0480e-01 1.5080e+00 1.5664e+00 5.6960e-01 1.5888e+00
#   9.0000e-01 1.1104e+00 1.2128e+00 1.1216e+00]
#  [1.3792e+00 1.3760e+00 1.3624e+00 1.4448e+00 1.1608e+00 8.4800e-01
#   1.6312e+00 1.2080e-01 1.2872e+00 1.3592e+00]
#  [3.2800e-01 7.7360e-01 1.2752e+00 6.9600e-01 1.2080e-01 1.8800e-01
#   1.2864e+00 0.0000e+00 5.7760e-01 7.4880e-01]
#  [8.0000e-04 3.4000e-01 7.5680e-01 9.1200e-02 0.0000e+00 9.6000e-03
#   2.6880e-01 0.0000e+00 1.0880e-01 1.1680e-01]
#  [0.0000e+00 1.8080e-01 1.4480e-01 6.4000e-03 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 8.0000e-04]]
# training accuracy:  0.7432150313152401
# validation accuracy:  0.6666666666666666
# total accuracy:  0.7346938775510204
# ------------------------------
# epoch:  1
# training......
# weights after epoch  1 :  [[0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 1.1200e-02 1.2000e-02 0.0000e+00 5.2800e-02
#   0.0000e+00 2.4000e-03 0.0000e+00 5.6000e-03]
#  [3.0560e-01 2.6960e-01 1.5336e+00 1.2632e+00 8.8000e-03 1.7976e+00
#   6.9600e-02 4.9360e-01 5.9440e-01 6.1120e-01]
#  [2.5184e+00 1.7304e+00 2.9888e+00 2.9456e+00 9.7680e-01 2.6200e+00
#   1.8912e+00 2.5448e+00 2.0616e+00 2.2344e+00]
#  [2.1272e+00 1.9112e+00 1.8488e+00 2.9000e+00 2.2720e+00 2.9392e+00
#   1.8312e+00 3.0488e+00 2.3648e+00 2.0360e+00]
#  [3.4480e-01 9.2080e-01 3.2320e-01 1.1952e+00 2.0480e-01 2.5704e+00
#   1.7920e-01 2.2600e+00 8.7840e-01 8.4400e-01]
#  [0.0000e+00 7.1200e-02 3.2000e-03 6.5600e-02 3.2000e-02 6.4160e-01
#   0.0000e+00 1.0192e+00 2.9600e-02 2.3200e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.7600e-02 0.0000e+00
#   0.0000e+00 1.6080e-01 0.0000e+00 8.0000e-04]
#  [0.0000e+00 0.0000e+00 1.6000e-03 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [6.1600e-02 2.4000e-03 6.0880e-01 4.8880e-01 8.0000e-04 4.4400e-01
#   1.6000e-03 4.7200e-02 1.7600e-01 1.4640e-01]
#  [2.3952e+00 5.1840e-01 2.9448e+00 2.5952e+00 3.6400e-01 3.2824e+00
#   9.4160e-01 1.9600e+00 2.5352e+00 2.4536e+00]
#  [2.6160e+00 2.7296e+00 2.1752e+00 1.3328e+00 2.8144e+00 2.3296e+00
#   3.1240e+00 2.1048e+00 1.9664e+00 1.6008e+00]
#  [1.9992e+00 3.0600e+00 2.4904e+00 1.8408e+00 1.5920e+00 1.2848e+00
#   9.0080e-01 1.9392e+00 1.7320e+00 1.6232e+00]
#  [2.0096e+00 1.6368e+00 9.7360e-01 2.3416e+00 2.7040e-01 9.6320e-01
#   1.1200e-01 2.5584e+00 2.3200e+00 1.9872e+00]
#  [6.5600e-02 1.4480e-01 4.2400e-02 2.4160e-01 1.6560e-01 2.0160e-01
#   3.2000e-03 9.8880e-01 2.0400e-01 2.8400e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 4.2400e-02 0.0000e+00
#   0.0000e+00 7.8400e-02 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [3.4640e-01 1.0480e-01 6.3680e-01 3.0480e-01 4.8000e-02 6.4960e-01
#   2.8000e-02 5.2800e-02 3.1600e-01 3.8240e-01]
#  [3.0408e+00 1.0464e+00 1.3304e+00 6.1120e-01 1.9616e+00 3.0536e+00
#   2.5920e+00 7.6320e-01 2.0984e+00 2.3392e+00]
#  [7.5760e-01 3.2880e+00 5.4080e-01 2.4480e-01 2.2864e+00 8.0320e-01
#   1.6312e+00 1.8400e-01 1.0896e+00 7.6800e-01]
#  [2.4000e-01 3.0744e+00 2.2464e+00 2.3168e+00 7.4160e-01 2.2640e-01
#   3.5200e-02 1.0400e+00 1.2672e+00 1.1784e+00]
#  [2.1592e+00 1.2832e+00 1.0176e+00 1.6096e+00 9.0160e-01 6.7200e-02
#   1.2800e-02 2.0248e+00 2.1944e+00 2.9128e+00]
#  [3.6880e-01 4.8800e-02 7.2800e-02 5.7600e-02 7.1520e-01 4.0000e-03
#   0.0000e+00 4.3120e-01 1.1920e-01 3.7280e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 2.4000e-02 0.0000e+00
#   0.0000e+00 5.6000e-03 0.0000e+00 4.8000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [4.5600e-01 2.8640e-01 8.9600e-02 2.4800e-02 4.5680e-01 5.4320e-01
#   1.7600e-01 4.4000e-02 7.6000e-02 1.3680e-01]
#  [2.4360e+00 1.7232e+00 1.9200e-01 7.9200e-02 3.1192e+00 2.9808e+00
#   2.9096e+00 5.9360e-01 1.4168e+00 2.0240e+00]
#  [1.7760e-01 3.3304e+00 7.0000e-01 1.4400e+00 8.0720e-01 2.2312e+00
#   1.4016e+00 8.8000e-01 2.5664e+00 2.3936e+00]
#  [8.0000e-03 3.0136e+00 2.3408e+00 3.2048e+00 1.2856e+00 1.5160e+00
#   6.2320e-01 2.3240e+00 2.6560e+00 2.6816e+00]
#  [1.3824e+00 1.0088e+00 7.3520e-01 8.9920e-01 1.7704e+00 5.3360e-01
#   2.3680e-01 2.3168e+00 1.0640e+00 3.0664e+00]
#  [7.4960e-01 2.0800e-02 1.0400e-02 3.2000e-03 8.7200e-01 3.5200e-02
#   6.4000e-03 7.6800e-01 4.0000e-02 3.5760e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 8.0000e-04 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.2240e-01 9.6800e-02 0.0000e+00 6.4000e-03 1.2320e+00 1.6880e-01
#   2.8000e-01 7.0400e-02 3.2000e-03 1.2000e-02]
#  [1.9432e+00 1.2296e+00 1.1200e-01 3.7600e-02 3.2008e+00 1.1920e+00
#   3.2584e+00 1.5296e+00 9.9040e-01 5.3520e-01]
#  [5.4400e-02 2.5800e+00 1.6976e+00 7.1600e-01 1.7072e+00 1.4904e+00
#   2.5800e+00 2.7984e+00 2.9816e+00 9.5600e-01]
#  [0.0000e+00 2.9752e+00 1.8112e+00 2.2784e+00 2.6400e+00 1.6368e+00
#   2.2952e+00 3.2072e+00 2.5528e+00 8.9680e-01]
#  [1.3992e+00 8.6240e-01 2.4800e-01 2.4248e+00 2.9744e+00 1.2400e+00
#   1.8352e+00 2.1832e+00 5.3680e-01 2.2024e+00]
#  [7.7920e-01 9.6000e-03 0.0000e+00 2.1440e-01 5.9920e-01 1.3040e-01
#   2.6560e-01 4.3200e-01 4.0000e-03 5.5360e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.0880e-01 2.4800e-02 5.5200e-02 5.6000e-02 8.6400e-01 1.0400e-02
#   8.5600e-02 9.3600e-02 9.2000e-02 0.0000e+00]
#  [2.5568e+00 9.2000e-01 9.4320e-01 1.5360e-01 2.1992e+00 1.5600e-01
#   3.1888e+00 7.3360e-01 2.0400e+00 3.0400e-02]
#  [1.3200e-01 2.0544e+00 2.2184e+00 2.0800e-02 2.4104e+00 5.9120e-01
#   2.0064e+00 2.0616e+00 1.4776e+00 8.7200e-02]
#  [1.4400e-01 2.8568e+00 1.1488e+00 4.1440e-01 3.1352e+00 1.3704e+00
#   8.1760e-01 1.9720e+00 1.5128e+00 2.9520e-01]
#  [1.9656e+00 9.3120e-01 1.5680e-01 2.3824e+00 2.0600e+00 1.4088e+00
#   1.7192e+00 5.1280e-01 1.2808e+00 1.6456e+00]
#  [6.9680e-01 9.6000e-03 7.8400e-02 9.6640e-01 1.1600e-01 2.9120e-01
#   1.5616e+00 2.9600e-02 9.6800e-02 7.0000e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   1.5200e-02 0.0000e+00 0.0000e+00 3.2000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 7.2000e-03 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [3.1200e-02 6.4000e-03 1.4480e-01 9.6000e-02 1.1440e-01 6.1600e-02
#   6.4000e-03 0.0000e+00 6.2400e-02 4.0000e-02]
#  [2.6032e+00 7.0720e-01 2.1112e+00 1.2568e+00 4.4560e-01 7.1280e-01
#   1.7272e+00 2.2160e-01 2.0296e+00 1.0304e+00]
#  [1.5392e+00 2.1976e+00 2.8256e+00 7.7520e-01 1.2520e+00 1.3288e+00
#   2.4592e+00 2.4888e+00 1.0544e+00 6.6720e-01]
#  [1.7688e+00 2.9360e+00 2.1264e+00 1.1448e+00 2.8584e+00 2.0560e+00
#   6.1920e-01 8.6880e-01 1.4168e+00 7.1200e-01]
#  [2.6440e+00 1.5432e+00 1.6096e+00 2.7168e+00 5.5600e-01 1.1744e+00
#   2.0592e+00 1.2000e-02 1.7000e+00 1.9976e+00]
#  [2.2640e-01 2.5680e-01 9.3600e-01 9.6880e-01 1.6000e-03 1.5440e-01
#   1.9688e+00 0.0000e+00 2.8960e-01 9.3040e-01]
#  [0.0000e+00 9.3600e-02 1.7600e-02 3.2000e-03 0.0000e+00 0.0000e+00
#   5.4400e-02 0.0000e+00 0.0000e+00 1.6000e-03]
#  [0.0000e+00 0.0000e+00 8.0000e-04 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 4.3200e-02 2.4000e-02 8.0000e-04 6.7200e-02
#   0.0000e+00 2.4000e-03 4.0000e-03 1.6000e-03]
#  [3.7600e-01 2.4160e-01 1.6296e+00 1.5960e+00 3.6800e-02 2.0472e+00
#   4.8800e-02 9.1280e-01 6.4720e-01 6.8000e-01]
#  [2.7088e+00 1.8320e+00 2.9864e+00 3.1696e+00 1.1496e+00 3.2504e+00
#   1.8512e+00 2.2528e+00 2.4488e+00 2.2808e+00]
#  [2.6800e+00 2.7808e+00 2.7752e+00 2.9568e+00 2.3336e+00 1.6576e+00
#   3.2744e+00 2.5760e-01 2.5968e+00 2.7488e+00]
#  [7.2480e-01 1.5968e+00 2.5400e+00 1.4760e+00 2.0880e-01 3.5200e-01
#   2.5872e+00 0.0000e+00 1.1560e+00 1.5504e+00]
#  [4.8000e-03 6.6640e-01 1.5568e+00 1.7840e-01 0.0000e+00 2.1600e-02
#   5.6400e-01 0.0000e+00 2.2960e-01 2.8880e-01]
#  [0.0000e+00 3.4240e-01 3.1760e-01 1.2800e-02 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 8.0000e-04]]
#
# training accuracy:  0.7292971468336813
# validation accuracy:  0.6666666666666666
# total accuracy:  0.7223252937538652
# ------------------------------
# epoch:  2
# training......
# weights after epoch  2 :  [[0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 2.6400e-02 2.1600e-02 0.0000e+00 7.8400e-02
#   0.0000e+00 2.4000e-03 2.4000e-03 6.4000e-03]
#  [4.6240e-01 3.8960e-01 2.2704e+00 1.8848e+00 2.1600e-02 2.5984e+00
#   8.8000e-02 7.7040e-01 8.6240e-01 9.5440e-01]
#  [3.7856e+00 2.5680e+00 4.4616e+00 4.3848e+00 1.4248e+00 3.9152e+00
#   2.9248e+00 3.7984e+00 3.0512e+00 3.3400e+00]
#  [3.1784e+00 2.8608e+00 2.7040e+00 4.4264e+00 3.3992e+00 4.3800e+00
#   2.7472e+00 4.5352e+00 3.6240e+00 2.9824e+00]
#  [4.4480e-01 1.3320e+00 5.2720e-01 1.7912e+00 3.1440e-01 3.8176e+00
#   2.4880e-01 3.4088e+00 1.3072e+00 1.2832e+00]
#  [0.0000e+00 1.0560e-01 5.6000e-03 9.1200e-02 4.0800e-02 1.0088e+00
#   0.0000e+00 1.4784e+00 4.3200e-02 3.5520e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 3.5200e-02 0.0000e+00
#   0.0000e+00 2.5280e-01 0.0000e+00 2.4000e-03]
#  [0.0000e+00 0.0000e+00 1.6000e-03 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 1.6000e-03 0.0000e+00]
#  [8.5600e-02 4.8000e-03 8.9040e-01 7.7120e-01 8.0000e-04 6.7280e-01
#   2.4000e-03 7.3600e-02 2.8720e-01 2.4640e-01]
#  [3.7136e+00 7.2960e-01 4.3976e+00 3.8024e+00 5.4800e-01 4.9224e+00
#   1.3904e+00 2.8464e+00 3.7680e+00 3.7056e+00]
#  [3.9816e+00 4.0904e+00 3.2216e+00 1.9768e+00 4.1536e+00 3.4344e+00
#   4.6832e+00 3.1608e+00 2.9752e+00 2.3720e+00]
#  [2.9880e+00 4.6080e+00 3.6648e+00 2.8240e+00 2.3920e+00 1.9336e+00
#   1.3592e+00 2.9016e+00 2.5224e+00 2.4264e+00]
#  [3.0944e+00 2.4328e+00 1.4600e+00 3.5344e+00 3.9120e-01 1.3680e+00
#   1.4880e-01 3.8112e+00 3.4232e+00 3.0096e+00]
#  [1.1040e-01 2.0880e-01 7.6800e-02 3.6400e-01 2.3920e-01 3.1600e-01
#   1.0400e-02 1.5200e+00 2.9760e-01 4.5200e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 6.3200e-02 0.0000e+00
#   0.0000e+00 1.1280e-01 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.1680e-01 1.6640e-01 9.4320e-01 4.6560e-01 7.2000e-02 1.0176e+00
#   4.8000e-02 7.6800e-02 4.9920e-01 6.1360e-01]
#  [4.5952e+00 1.5888e+00 1.9392e+00 9.2480e-01 2.9208e+00 4.5920e+00
#   3.7688e+00 1.1464e+00 3.1024e+00 3.5256e+00]
#  [1.0952e+00 4.9264e+00 8.5040e-01 3.7280e-01 3.3936e+00 1.2640e+00
#   2.5096e+00 3.0720e-01 1.6096e+00 1.1344e+00]
#  [3.4480e-01 4.6160e+00 3.3816e+00 3.5400e+00 1.1168e+00 3.7200e-01
#   6.0000e-02 1.5272e+00 1.9152e+00 1.8016e+00]
#  [3.1800e+00 1.9760e+00 1.5112e+00 2.3856e+00 1.3312e+00 1.0480e-01
#   1.6800e-02 2.9816e+00 3.1528e+00 4.3680e+00]
#  [5.5120e-01 7.9200e-02 1.0800e-01 1.1120e-01 1.0864e+00 6.4000e-03
#   0.0000e+00 6.4720e-01 1.8640e-01 5.1520e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 3.2000e-02 0.0000e+00
#   0.0000e+00 1.1200e-02 0.0000e+00 7.2000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [6.8080e-01 3.9920e-01 1.4160e-01 4.6400e-02 7.3520e-01 8.2000e-01
#   2.5760e-01 6.6400e-02 1.2000e-01 1.8000e-01]
#  [3.6056e+00 2.5256e+00 3.0560e-01 1.3680e-01 4.6696e+00 4.5536e+00
#   4.2960e+00 9.1600e-01 2.0736e+00 3.0440e+00]
#  [2.7280e-01 4.9752e+00 1.0432e+00 2.1480e+00 1.2808e+00 3.4376e+00
#   2.0896e+00 1.2712e+00 3.8888e+00 3.5704e+00]
#  [8.0000e-03 4.5408e+00 3.5760e+00 4.7840e+00 1.9864e+00 2.3008e+00
#   9.2880e-01 3.4848e+00 3.9584e+00 4.0720e+00]
#  [2.0160e+00 1.4928e+00 1.0552e+00 1.3432e+00 2.6352e+00 7.6560e-01
#   3.4880e-01 3.5312e+00 1.5584e+00 4.6520e+00]
#  [1.0528e+00 3.6800e-02 2.1600e-02 3.2000e-03 1.3440e+00 5.0400e-02
#   6.4000e-03 1.1576e+00 6.0000e-02 5.1920e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 8.0000e-04 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [7.9680e-01 1.3280e-01 0.0000e+00 8.8000e-03 1.8104e+00 2.4400e-01
#   4.3600e-01 9.9200e-02 1.4400e-02 1.9200e-02]
#  [2.9536e+00 1.8752e+00 1.7360e-01 8.8000e-02 4.7648e+00 1.7568e+00
#   4.8864e+00 2.3120e+00 1.4856e+00 7.7440e-01]
#  [8.7200e-02 3.8552e+00 2.4808e+00 1.1104e+00 2.5616e+00 2.2456e+00
#   3.8352e+00 4.1712e+00 4.5056e+00 1.4032e+00]
#  [0.0000e+00 4.4768e+00 2.6816e+00 3.4296e+00 3.9104e+00 2.4576e+00
#   3.4888e+00 4.7632e+00 3.8120e+00 1.2800e+00]
#  [2.0368e+00 1.2456e+00 3.3840e-01 3.6736e+00 4.4224e+00 1.8960e+00
#   2.7312e+00 3.2328e+00 7.4240e-01 3.3248e+00]
#  [1.1592e+00 1.6000e-02 0.0000e+00 3.1120e-01 8.8960e-01 1.8880e-01
#   3.5200e-01 6.3120e-01 6.4000e-03 8.4400e-01]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 4.0000e-03 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [3.3200e-01 3.6800e-02 7.6800e-02 7.7600e-02 1.2728e+00 1.8400e-02
#   1.4080e-01 1.3360e-01 1.3840e-01 1.2800e-02]
#  [3.8456e+00 1.3952e+00 1.4096e+00 2.5680e-01 3.2352e+00 2.2160e-01
#   4.8176e+00 1.0688e+00 3.0184e+00 4.1600e-02]
#  [2.0480e-01 3.1464e+00 3.3392e+00 3.2000e-02 3.6184e+00 8.8160e-01
#   2.9600e+00 3.1760e+00 2.1696e+00 1.3280e-01]
#  [2.0000e-01 4.3304e+00 1.7016e+00 6.6320e-01 4.7168e+00 2.1224e+00
#   1.2200e+00 2.9544e+00 2.2576e+00 4.4960e-01]
#  [2.9792e+00 1.4352e+00 2.1520e-01 3.5296e+00 3.0784e+00 2.1048e+00
#   2.6160e+00 7.9600e-01 1.9712e+00 2.3864e+00]
#  [1.0032e+00 1.8400e-02 1.1280e-01 1.4752e+00 1.6320e-01 4.4560e-01
#   2.3120e+00 5.2800e-02 1.2560e-01 1.0944e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   2.4800e-02 0.0000e+00 0.0000e+00 3.2000e-03]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 8.0000e-03 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [4.3200e-02 6.4000e-03 2.0640e-01 1.3040e-01 1.9760e-01 9.0400e-02
#   8.0000e-03 8.0000e-04 9.6000e-02 5.8400e-02]
#  [3.8680e+00 1.0584e+00 3.1568e+00 1.8784e+00 6.3920e-01 1.0888e+00
#   2.5664e+00 3.3920e-01 3.0472e+00 1.5680e+00]
#  [2.3408e+00 3.3072e+00 4.2288e+00 1.1448e+00 1.8688e+00 1.9472e+00
#   3.6016e+00 3.7616e+00 1.6048e+00 9.7200e-01]
#  [2.6080e+00 4.3544e+00 3.1480e+00 1.7072e+00 4.2816e+00 3.0808e+00
#   9.2320e-01 1.3072e+00 2.0912e+00 1.0672e+00]
#  [3.9416e+00 2.2512e+00 2.4216e+00 4.0704e+00 8.7120e-01 1.7624e+00
#   2.9376e+00 1.7600e-02 2.5768e+00 3.0016e+00]
#  [3.4080e-01 3.6960e-01 1.3728e+00 1.4264e+00 1.6000e-03 2.5040e-01
#   3.0312e+00 0.0000e+00 4.3120e-01 1.3280e+00]
#  [0.0000e+00 1.3600e-01 3.8400e-02 3.2000e-03 0.0000e+00 0.0000e+00
#   8.0000e-02 0.0000e+00 0.0000e+00 7.2000e-03]
#  [0.0000e+00 0.0000e+00 8.0000e-04 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [8.0000e-04 0.0000e+00 6.1600e-02 2.4000e-02 8.0000e-04 9.3600e-02
#   0.0000e+00 2.4000e-03 5.6000e-03 2.4000e-03]
#  [5.6160e-01 3.7920e-01 2.5112e+00 2.3496e+00 3.6800e-02 3.0880e+00
#   1.0160e-01 1.3560e+00 9.7920e-01 1.0072e+00]
#  [4.0912e+00 2.7568e+00 4.4384e+00 4.7128e+00 1.7448e+00 4.8816e+00
#   2.6696e+00 3.2736e+00 3.6424e+00 3.4128e+00]
#  [3.9736e+00 4.2440e+00 4.1176e+00 4.5016e+00 3.4864e+00 2.5120e+00
#   4.9472e+00 3.7920e-01 3.8816e+00 4.1120e+00]
#  [1.0696e+00 2.4208e+00 3.7872e+00 2.1488e+00 2.9440e-01 5.3440e-01
#   3.9320e+00 8.0000e-04 1.6776e+00 2.3672e+00]
#  [1.3600e-02 1.0056e+00 2.3504e+00 2.4800e-01 0.0000e+00 3.1200e-02
#   8.9440e-01 0.0000e+00 3.2560e-01 4.8320e-01]
#  [0.0000e+00 5.0560e-01 4.7120e-01 1.2800e-02 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 4.0000e-03]]
#
# training accuracy:  0.7404314544189283
# validation accuracy:  0.6666666666666666
# total accuracy:  0.7322201607915894
# ------------------------------

# %% [markdown]
# ## Validation Testing

# %%
validate(X_train, X_val, weights, 0, len(X_train)+len(X_test))
# Out:
# training accuracy:  0.7543493389004872
# validation accuracy:  0.6444444444444445
# total accuracy:  0.7421150278293135

# %% [markdown]
# ## Final Testing

# %%
accuracy = sim(X_test, weights, len(X_train))
print("accuracy: ", accuracy)
# Out:
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  0
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  4
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  0
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  6
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  7
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  4
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  8
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  0
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  6
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  8
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  8
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  2
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# accuracy:  0.6333333333333333

# %% [markdown]
# ## Digit Classification - 2 digits
#
# In this section, we analyze the potential flaws of this kind of architecture when evaluating similar images. When distinguishing between 8 and 3, which are significantly more similar than 1 and 3, we see that the accuracy of our network when performing such a task is much higher for the latter than the former.

# %%
test_bin = []
test_ind = []
for i in range(len(X_test)):
    if (digits.target[len(X_train)+i] == 1) or (digits.target[len(X_train)+i] == 3):
        #print("adding digit")
        test_bin.append(X_test[i])
        test_ind.append(digits.target[len(X_train)+i])

count = 0
for i in range (len(test_bin)):
    if test_ind[i] == _predict(test_bin[i], weights):
        count+=1
print("accuracy for classifying 1 and 3: ", count/len(test_bin))

test_bin = []
test_ind = []
for i in range(len(X_test)):
    if (digits.target[len(X_train)+i] == 8) or (digits.target[len(X_train)+i] == 3):
        #print("adding digit")
        test_bin.append(X_test[i])
        test_ind.append(digits.target[len(X_train)+i])

count = 0
for i in range (len(test_bin)):
    if test_ind[i] == _predict(test_bin[i], weights):
        count+=1
print("accuracy for classifying 8 and 3: ", count/len(test_bin))

#print(test_bin)
# Out:
# accuracy for classifying 1 and 3:  0.75
# accuracy for classifying 8 and 3:  0.34285714285714286
