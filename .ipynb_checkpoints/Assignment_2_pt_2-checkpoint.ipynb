# %%
pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\mzig2\anaconda3\lib\site-packages (0.23.2)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (0.14.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\mzig2\anaconda3\lib\site-packages (from scikit-learn) (1.17.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\mzig2\anaconda3\lib\site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install import_ipynb
# Out:
# Requirement already satisfied: import_ipynb in c:\users\mzig2\anaconda3\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %% [markdown]
# ## Data Management

# %%
from sklearn.datasets import load_digits
 
digits = load_digits()
import matplotlib.pyplot as plt 
plt.matshow(digits.images[0]) 
plt.show()

# %%
#flattening to 1D arrays
#partitioning to training set, testing set, validation set
from sklearn.model_selection import train_test_split
X_train, X_other, y_train, y_other = train_test_split(digits.data, digits.images, test_size=0.2, shuffle=False)
X_test, X_val, y_test, y_val = train_test_split(X_other, y_other, test_size=0.5, shuffle=False)
print("Numbers to train: " + str(len(X_train)))
print("Numbers to test: " + str(len(X_test)))
print("Numbers to validate: " + str(len(X_val)))
# Out:
# Numbers to train: 1437
# Numbers to test: 180
# Numbers to validate: 180

# %% [markdown]
# ### Test set starts after training set in partition
# ### Validation set starts after test set

# %%
i=36
plt.matshow(X_test[i].reshape(8,8))
print(digits.target[len(X_train)+i])
# Out:
# 6

# %% [markdown]
# ## Poisson Encoding

# %% [markdown]
# ### 2.2.d)
#
# For this modified SNN, we decided to employ a Poisson Encoding scheme in order to generate a spike train representation for each of our images. Citing this paper https://arxiv.org/ftp/arxiv/papers/1604/1604.06751.pdf, our algorithm for doing so was as follows:
#
# - normalize all r rate (pixel intensity) values to be between 0 and 1
# - generate M uniform random numbers between 0 and 1 where M is equal to the number of bins of time we're examining spiking   activity (since dT = 1, M will be equal to the size of the array)
# - for all i in M random numbers in rand, if r[i] > rand[i], generate 1 spike
#
# After executing this process, 3 arrays will be returned of size M: one containing the normalized pixel intensities of each bin, one containing their binary spike values, and one consisting of the maximum amount of intensity at each index where a spike occurs for plotting purposes.

# %%
def poissonEncoding(rates):
    """
    Transforms a 1D array of inputs representing an image into spike train representation utilizing Poisson method of
    encoding
    
    Params:
        rates: 1D array of inputs (in this case, pixel intensitiies corresponding to our image)
    Returns:
        n_rates: Normalized set of input pixel values (represents probabilities of a spike occurring at each dT)
        bin_spikes: 1D array of binary values representing timesteps in which spikes occur
        p_spikes: 1D array representing pixel intensities of spike train representation for plotting/computation purposes
        
    """
    dT = 1
    
    max = np.amax(rates)
    n_rates = (rates*dT)/max
    
    rand = np.random.uniform(0,1, len(rates))
    bin_spikes = np.zeros(len(rates))
    pix_spikes = np.zeros(len(rates))
    
    for i in range(len(rates)):
        if n_rates[i] > rand[i]:
            bin_spikes[i] = 1
            pix_spikes[i] = max
                    
    return n_rates, bin_spikes, pix_spikes

# %%
plt.matshow(np.reshape(X_train[0], (8,8))) 
print(digits.target[0])
n, b, p = poissonEncoding(X_train[0])
plt.matshow(p.reshape(8,8))
plt.show()

len(digits.images)
# Out:
# 0
# 1797

# %% [markdown]
#  ## Network Functions

# %%
def train(X, Y, val, l_rt, init, epochs):
    
    weights = init
    
    for i in range(epochs):
        
        print("epoch: ", i)
        print("training......")
        for x in range(len(X)):
            
            true_index = digits.target[x]
            #print("index: ", x, " true index: ", true_index)
            in_neurons = X[x]
            out_neurons = Y[x]
            
            X_n_rts, X_bins, X_pixs = poissonEncoding(in_neurons)
                        
            weight_adjs = np.zeros((len(in_neurons),10))
            
            y_out  = np.zeros((10,len(in_neurons)))
            y_out[true_index] = out_neurons.flatten()
                        
            for pix in range(len(in_neurons)):
                for digit in range(10):
                   weight_adjs[pix][digit] = l_rt*X_bins[pix]*y_out[digit][pix]
                
            weights = weights + weight_adjs
            
            if (i == 0) and (x % 250 == 0):
                print("********************")
                print("validating after ",x,"th image:")
                validate(X,val,weights.T,0,len(X_train)+len(X_test))
                
        print("weights after epoch ", i,": ", weights, "\n")
        validate(X, val, weights.T, 0, len(X_train)+len(X_test))
        print("------------------------------")
        
        
    return weights.T


def validate(train, val, weights, ind_train, ind_val):
    
    train_correct = 0
    val_correct = 0
    
    for i in range(len(train)):
        prediction = _predict(train[i], weights)
        if prediction == digits.target[ind_train+i]:
            train_correct+=1
    train_accuracy = train_correct/len(train)
    print("training accuracy: ", train_accuracy)
    
    for j in range(len(val)):
        prediction = _predict(val[j], weights)
        if prediction == digits.target[ind_val+j]:
            val_correct+=1
    val_accuracy = val_correct/len(val)
    print("validation accuracy: ", val_accuracy)
    
    print("total accuracy: ", (train_correct+val_correct)/(len(train)+len(val)))
    
        

def predict(test, weights, targ):
    
    print("image value: ", targ)
    
    n, spikes, p = poissonEncoding(test)
    outs = np.zeros(len(weights))
    for i in range(len(weights)):
        outs[i] = np.dot(spikes, weights[i])
    
    prediction = np.argmax(outs)
    
    print("predicted value: ", prediction)
    
    if (prediction == targ):
        return True
    else:
        return False
    
def _predict(test, weights):
    
    n, spikes, p = poissonEncoding(test)
    outs = np.zeros(len(weights))
    
    for i in range(len(weights)):
        outs[i] = np.dot(spikes, weights[i])
    
    return np.argmax(outs)
    
def sim(test, weights, ind_targ):
    
    correct = 0
    
    for i in range(len(test)):
        
        x = predict(test[i], weights, digits.target[ind_targ+i])
        
        print("prediction correct: ", x)
        print("------------------------------")
        
        if x:
            correct += 1
            
    return correct/len(test)

# %% [markdown]
# ## Training

# %%
init_weights = np.zeros((len(X_train[0]),10))

#w_i,j = w_out,pix
weights = train(X_train, y_train, X_val, 0.0008, init_weights, 3)
# Out:
# epoch:  0
# training......
# ********************
# validating after  0 th image:
# training accuracy:  0.09951287404314545
# validation accuracy:  0.08888888888888889
# total accuracy:  0.09833024118738404
# ********************
# validating after  250 th image:
# training accuracy:  0.6116910229645094
# validation accuracy:  0.5833333333333334
# total accuracy:  0.608534322820037
# ********************
# validating after  500 th image:
# training accuracy:  0.605427974947808
# validation accuracy:  0.55
# total accuracy:  0.5992578849721707
# ********************
# validating after  750 th image:
# training accuracy:  0.6311760612386917
# validation accuracy:  0.55
# total accuracy:  0.6221397649969078
# ********************
# validating after  1000 th image:
# training accuracy:  0.686151704940849
# validation accuracy:  0.6333333333333333
# total accuracy:  0.6802721088435374
# ********************
# validating after  1250 th image:
# training accuracy:  0.6917188587334725
# validation accuracy:  0.6222222222222222
# total accuracy:  0.683982683982684
# weights after epoch  0 :  [[0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00
#   2.8912e+00 1.7600e-02 2.5776e+00 2.9032e+00]
#  [2.9360e-01 4.2320e-01 1.2600e+00 1.4112e+00 8.0000e-04 2.7760e-01
#   2.9984e+00 0.0000e+00 4.1360e-01 1.2416e+00]
#  [0.0000e+00 9.3600e-02 4.9600e-02 1.3600e-02 0.0000e+00 0.0000e+00
#   6.2400e-02 0.0000e+00 8.0000e-04 8.0000e-04]
#  [0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 5.2800e-02 3.9200e-02 0.0000e+00 8.6400e-02
#   0.0000e+00 0.0000e+00 5.6000e-03 0.0000e+00]
#  [4.7360e-01 3.6960e-01 2.5896e+00 2.2864e+00 3.0400e-02 3.0888e+00
#   1.2480e-01 1.3472e+00 9.4480e-01 1.0216e+00]
#  [4.0880e+00 2.6400e+00 4.3776e+00 4.7216e+00 1.7760e+00 4.9168e+00
#   2.7200e+00 3.3568e+00 3.6288e+00 3.4240e+00]
#  [4.1136e+00 4.1872e+00 4.0200e+00 4.5544e+00 3.4912e+00 2.5176e+00
#   4.8944e+00 3.3520e-01 3.8296e+00 4.0808e+00]
#  [1.0440e+00 2.5560e+00 3.6656e+00 2.1176e+00 2.8000e-01 5.2400e-01
#   4.0632e+00 8.0000e-04 1.7976e+00 2.5112e+00]
#  [2.4800e-02 9.7360e-01 2.3856e+00 2.1840e-01 0.0000e+00 3.2000e-03
#   8.5840e-01 0.0000e+00 2.7280e-01 5.3200e-01]
#  [0.0000e+00 4.3920e-01 4.2400e-01 1.8400e-02 0.0000e+00 0.0000e+00
#   8.0000e-03 0.0000e+00 0.0000e+00 1.6000e-03]]
#
# training accuracy:  0.7418232428670842
# validation accuracy:  0.7
# total accuracy:  0.7371675943104514
# ------------------------------

# %% [markdown]
# ## Validation Testing

# %%
validate(X_train, X_val, weights, 0, len(X_train)+len(X_test))
# Out:
# training accuracy:  0.7251217814892137
# validation accuracy:  0.7
# total accuracy:  0.7223252937538652

# %% [markdown]
# ## Final Testing

# %%
accuracy = sim(X_test, weights, len(X_train))
print("accuracy: ", accuracy)
# Out:
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  4
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  4
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  8
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  8
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  7
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  0
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  3
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  7
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  3
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  9
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  5
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  6
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  4
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  7
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  0
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  7
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  8
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  2
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  2
# predicted value:  2
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  7
# predicted value:  2
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  7
# prediction correct:  False
# ------------------------------
# image value:  3
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  4
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  6
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  6
# predicted value:  6
# prediction correct:  True
# ------------------------------
# image value:  4
# predicted value:  7
# prediction correct:  False
# ------------------------------
# image value:  9
# predicted value:  1
# prediction correct:  False
# ------------------------------
# image value:  1
# predicted value:  1
# prediction correct:  True
# ------------------------------
# image value:  5
# predicted value:  5
# prediction correct:  True
# ------------------------------
# image value:  0
# predicted value:  0
# prediction correct:  True
# ------------------------------
# image value:  9
# predicted value:  9
# prediction correct:  True
# ------------------------------
# accuracy:  0.6555555555555556

# %% [markdown]
# ## Digit Classification - 2 digits

# %%
test_bin = []
test_ind = []
for i in range(len(X_test)):
    if (digits.target[len(X_train)+i] == 1) or (digits.target[len(X_train)+i] == 3):
        #print("adding digit")
        test_bin.append(X_test[i])
        test_ind.append(digits.target[len(X_train)+i])

count = 0
for i in range (len(test_bin)):
    if test_ind[i] == _predict(test_bin[i], weights):
        count+=1
print("accuracy for classifying 1 and 3: ", count/len(test_bin))

test_bin = []
test_ind = []
for i in range(len(X_test)):
    if (digits.target[len(X_train)+i] == 8) or (digits.target[len(X_train)+i] == 3):
        #print("adding digit")
        test_bin.append(X_test[i])
        test_ind.append(digits.target[len(X_train)+i])

count = 0
for i in range (len(test_bin)):
    if test_ind[i] == _predict(test_bin[i], weights):
        count+=1
print("accuracy for classifying 8 and 3: ", count/len(test_bin))

#print(test_bin)
# Out:
# accuracy for classifying 1 and 3:  0.7222222222222222
# accuracy for classifying 8 and 3:  0.45714285714285713
